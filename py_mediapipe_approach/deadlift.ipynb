# %%
# %pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (0.9.1.0)
# Requirement already satisfied: opencv-python in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: pandas in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: scikit-learn in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: absl-py in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (1.26.2)
# Requirement already satisfied: opencv-contrib-python in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eduardfer/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages (from matplotlib->mediapipe) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mediapipe as mp
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %% [markdown]
# # First step

# %%
cap = cv2.VideoCapture(0)
with mp_pose.Pose(
    min_detection_confidence=0.5, min_tracking_confidence=0.5
) as pose:  # Setup mediapipe instance
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor image
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Render detections
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2),
        )
        
        cv2.imshow("Raw Webcam Feed", image)

        if cv2.waitKey(10) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# 2024-02-13 22:47:19.371 python[15978:349467] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# # Save Video

# %%
cap = cv2.VideoCapture(0)

height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps = cap.get(cv2.CAP_PROP_FPS)
video_writer = cv2.VideoWriter('deadlift.avi', cv2.VideoWriter_fourcc('P', 'I', 'M', '1'), fps, (int(width), int(height)))

while cap.isOpened():
    ret, frame = cap.read()
    
    cv2.imshow('Press', frame)
    video_writer.write(frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
    

cap.release()
# video_writer.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cap = cv2.VideoCapture('./videos/front_high.mov')
#       3 height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
#       4 width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# # Capture Landmarks & Export to CSV

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
landmarks = ['class']
for val in range(1, 33+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
def export_landmark(results, action):
    try:
        keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        keypoints = np.insert(keypoints.astype(object), 0, action)
        
        with open('coords.csv', mode='a', newline='') as f:
            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
    except Exception as e:
        print(e)
        pass

# %%
cap = cv2.VideoCapture('benchpress.mp4')
count = 0
with mp_pose.Pose(
    min_detection_confidence=0.5, min_tracking_confidence=0.5
) as pose:  # Setup mediapipe instance
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor image
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Render detections
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2),
        )
        
        k = cv2.waitKey(1)
        if k == 119:
            export_landmark(results, 'up')
        if k == 115:
            export_landmark(results, 'down')
        
        cv2.imshow("Raw Webcam Feed", image)
        count += 1

        if cv2.waitKey(10) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Train Custom Model Using Scikit Learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#   class        x1        y1        z1        v1        x2        y2        z2  \
# 0  down  0.400498  0.419187 -0.071906  0.999941  0.386171  0.413787 -0.049498
# 1    up  0.402263  0.420550 -0.039944  0.999962  0.387833  0.417942 -0.019979
# 2    up  0.391951  0.423795 -0.020689  0.999961  0.379638  0.420832  0.001790
# 3    up  0.391103  0.427886 -0.018901  0.999967  0.378304  0.425721  0.003232
# 4    up  0.398831  0.427938 -0.017454  0.999978  0.389333  0.419746  0.011327
#
#          v2        x3  ...       z31       v31       x32       y32       z32  \
columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1234)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier())
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(x_train, y_train)
    fit_models[algo] = model

# %%
fit_models['rc'].predict(x_test)
# Out:
# array(['down', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'up',
#        'down', 'down', 'down', 'up'], dtype='<U4')

# %% [markdown]
# # Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test.values, yhat),
          precision_score(y_test.values, yhat, average="binary", pos_label="up"),
          recall_score(y_test.values, yhat, average="binary", pos_label="up"))
# Out:
# lr 0.9230769230769231 0.875 1.0
# rc 0.9230769230769231 1.0 0.8571428571428571
# rf 1.0 1.0 1.0
# gb 0.9230769230769231 1.0 0.8571428571428571

# %%
yhat = fit_models['rc'].predict(x_test)

# %%
yhat[:10]
# Out:
# array(['down', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'up',
#        'down'], dtype='<U4')

# %%
y_test
fit_models['lr'].fit(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 y_test
# ----> 2 fit_models['lr'].fit(x)
#
# File ~/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages/sklearn/pipeline.py:427, in Pipeline.fit(self, X, y, **fit_params)
#     425     if self._final_estimator != "passthrough":
#     426         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 427         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     429 return self
#
# File ~/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1208, in LogisticRegression.fit(self, X, y, sample_weight)
#    1205 else:
#    1206     _dtype = [np.float64, np.float32]
# -> 1208 X, y = self._validate_data(
#    1209     X,
#    1210     y,
#    1211     accept_sparse="csr",
#    1212     dtype=_dtype,
#    1213     order="C",
#    1214     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1215 )
#    1216 check_classification_targets(y)
#    1217 self.classes_ = np.unique(y)
#
# File ~/Desktop/TFG TELEMÀTICA/eGym-ML_Testing/egym_ml/lib/python3.11/site-packages/sklearn/base.py:583, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     580 self._check_feature_names(X, reset=reset)
#     582 if y is None and self._get_tags()["requires_y"]:
# --> 583     raise ValueError(
#     584         f"This {self.__class__.__name__} estimator "
#     585         "requires y to be passed, but the target y is None."
#     586     )
#     588 no_val_X = isinstance(X, str) and X == "no_validation"
#     589 no_val_y = y is None or isinstance(y, str) and y == "no_validation"
#
# ValueError: This LogisticRegression estimator requires y to be passed, but the target y is None.

# %%
with open('deadlift1.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # Make Detections with Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
with open('deadlift.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
cap = cv2.VideoCapture(0)

counter = 0
current_stage = None

with mp_pose.Pose(
    min_detection_confidence=0.5, min_tracking_confidence=0.5
) as pose:  # Setup mediapipe instance
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor image
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Render detections
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66),
                                   thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230),
                                   thickness=2, circle_radius=2),
        )

        try:
            row = np.array(
                [
                    [res.x, res.y, res.z, res.visibility]
                    for res in results.pose_landmarks.landmark
                ]
            ).flatten()
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            
            if body_language_class == 'down' and body_language_prob[body_language_prob.argmax()] <= .75:
                current_stage = 'down'
            elif current_stage == 'down' and body_language_class == 'up' and body_language_prob[body_language_prob.argmax()] > .75:
                current_stage = 'up'
                counter += 1

            cv2.rectangle(image, (0, 0), (250, 60), (245, 117, 16), -1)

            cv2.putText(
                image,
                "CLASS",
                (95, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                body_language_class.split(" ")[0],
                (90, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )

            cv2.putText(
                image,
                "PROB",
                (15, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                str(round(
                    body_language_prob[np.argmax(body_language_prob)], 2)),
                (10, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )
            
            cv2.putText(
                image,
                "COUNT",
                (180, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                str(round(
                    counter)),
                (175, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )

        except Exception as e:
            pass

        cv2.imshow("Raw Webcam Feed", image)

        if cv2.waitKey(10) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# 2024-02-13 22:51:53.566 python[16447:356744] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
with open('deadlift1.pkl', 'rb') as f:
    model = pickle.load(f)
    
cap = cv2.VideoCapture(0)

counter = 0
current_stage = None

with mp_pose.Pose(
    min_detection_confidence=0.5, min_tracking_confidence=0.5
) as pose:  # Setup mediapipe instance
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor image
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Render detections
        mp_drawing.draw_landmarks(
            image,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66),
                                   thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230),
                                   thickness=2, circle_radius=2),
        )

        try:
            row = np.array(
                [
                    [res.x, res.y, res.z, res.visibility]
                    for res in results.pose_landmarks.landmark
                ]
            ).flatten()
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            
            if body_language_class == 'down' and body_language_prob[body_language_prob.argmax()] <= .75:
                current_stage = 'down'
            elif current_stage == 'down' and body_language_class == 'up' and body_language_prob[body_language_prob.argmax()] > .75:
                current_stage = 'up'
                counter += 1

            cv2.rectangle(image, (0, 0), (250, 60), (245, 117, 16), -1)

            cv2.putText(
                image,
                "CLASS",
                (95, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                body_language_class.split(" ")[0],
                (90, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )

            cv2.putText(
                image,
                "PROB",
                (15, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                str(round(
                    body_language_prob[np.argmax(body_language_prob)], 2)),
                (10, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )
            
            cv2.putText(
                image,
                "COUNT",
                (180, 12),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 0),
                1,
                cv2.LINE_AA,
            )
            cv2.putText(
                image,
                str(round(
                    counter)),
                (175, 40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2,
                cv2.LINE_AA,
            )

        except Exception as e:
            pass

        cv2.imshow("Raw Webcam Feed", image)

        if cv2.waitKey(10) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
